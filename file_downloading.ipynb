# %%
# !pip install gdown requests
# Out:
# Collecting gdown
#   Obtaining dependency information for gdown from https://files.pythonhosted.org/packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: requests in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from gdown) (4.12.3)
# Collecting filelock (from gdown)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/4d/36/2a115987e2d8c300a974597416d9de88f2444426de9571f4b59b2cca3acc/filelock-3.18.0-py3-none-any.whl.metadata
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tqdm in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/oleksandrsiryi/PycharmProjects/Ma_2/.venv/lib/python3.12/site-packages (from requests) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Installing collected packages: filelock, gdown
# Successfully installed filelock-3.18.0 gdown-5.2.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import gdown

folder_url = "https://drive.google.com/drive/folders/1p5s4APqO8szykm3LLf0jDp8q2D89H4o0?usp=drive_link"
output_dir = "data"

os.makedirs(output_dir, exist_ok=True)

# Запуск завантаження
gdown.download_folder(url=folder_url, output=output_dir, quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Processing file 15HGsB0G8vjR39NBdZ4VUu7FohtA59C51 Odata2019File.csv
# Processing file 1-2aabT9LsH_BgpeHF7lR25BKdt4OV5Ci Odata2020File.csv
# Processing file 1nMjxH4M2UcrH2hgOhcoyMA4-pcv2cHHT Odata2021File.csv
# Processing file 1WxBNsa6GP6yMIYaZLnS1Ux2h5mW0CYkr Odata2022File.csv
# Processing file 1izq-IN5_0eOiiYEc1edpmldq0qhVP7KU Odata2023File.csv
# Processing file 1-qh7AIyOdtB7zX7ty33dKwL6u0kvF3RE Odata2024File.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=15HGsB0G8vjR39NBdZ4VUu7FohtA59C51
# From (redirected): https://drive.google.com/uc?id=15HGsB0G8vjR39NBdZ4VUu7FohtA59C51&confirm=t&uuid=1feaa42f-7bf2-4da5-b64d-c1c5158540eb
# To: /Users/oleksandrsiryi/PycharmProjects/NMT-EIT-Research/data/Odata2019File.csv
# 100%|██████████| 523M/523M [00:45<00:00, 11.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1-2aabT9LsH_BgpeHF7lR25BKdt4OV5Ci
# From (redirected): https://drive.google.com/uc?id=1-2aabT9LsH_BgpeHF7lR25BKdt4OV5Ci&confirm=t&uuid=3e043cbd-88ef-49d2-ae37-d4ecb6e8f1a1
# To: /Users/oleksandrsiryi/PycharmProjects/NMT-EIT-Research/data/Odata2020File.csv
# 100%|██████████| 577M/577M [00:50<00:00, 11.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1nMjxH4M2UcrH2hgOhcoyMA4-pcv2cHHT
# From (redirected): https://drive.google.com/uc?id=1nMjxH4M2UcrH2hgOhcoyMA4-pcv2cHHT&confirm=t&uuid=7fca4a6b-fe42-45c6-9475-451e08d1165a
# To: /Users/oleksandrsiryi/PycharmProjects/NMT-EIT-Research/data/Odata2021File.csv
# 100%|██████████| 1.22G/1.22G [01:45<00:00, 11.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1WxBNsa6GP6yMIYaZLnS1Ux2h5mW0CYkr
# From (redirected): https://drive.google.com/uc?id=1WxBNsa6GP6yMIYaZLnS1Ux2h5mW0CYkr&confirm=t&uuid=f49f68c7-85bc-453a-b0a3-c6befd1d8485
# To: /Users/oleksandrsiryi/PycharmProjects/NMT-EIT-Research/data/Odata2022File.csv
# 100%|██████████| 225M/225M [00:19<00:00, 11.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1izq-IN5_0eOiiYEc1edpmldq0qhVP7KU
# From (redirected): https://drive.google.com/uc?id=1izq-IN5_0eOiiYEc1edpmldq0qhVP7KU&confirm=t&uuid=2b1d8d57-5338-4b3d-ad81-671155b6d698
# To: /Users/oleksandrsiryi/PycharmProjects/NMT-EIT-Research/data/Odata2023File.csv
# 100%|██████████| 331M/331M [00:28<00:00, 11.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1-qh7AIyOdtB7zX7ty33dKwL6u0kvF3RE
# From (redirected): https://drive.google.com/uc?id=1-qh7AIyOdtB7zX7ty33dKwL6u0kvF3RE&confirm=t&uuid=e4fd3a40-c897-4716-9633-3dd9da4fbced
# To: /Users/oleksandrsiryi/PycharmProjects/NMT-EIT-Research/data/Odata2024File.csv
# 100%|██████████| 404M/404M [00:35<00:00, 11.5MB/s]
# Download completed
# ['data/Odata2019File.csv',
#  'data/Odata2020File.csv',
#  'data/Odata2021File.csv',
#  'data/Odata2022File.csv',
#  'data/Odata2023File.csv',
#  'data/Odata2024File.csv']

# %%
import os
import re

# Шлях до папки з файлами
folder_path = "data"

# Проходимо по всіх файлах у папці
for filename in os.listdir(folder_path):
    # Шукаємо рік у назві, наприклад "Odata2021File.csv"
    match = re.search(r'Odata(\d{4})', filename)
    if match:
        year = match.group(1)
        old_path = os.path.join(folder_path, filename)
        new_filename = f"{year}.csv"
        new_path = os.path.join(folder_path, new_filename)

        # Перейменування
        os.rename(old_path, new_path)
        print(f"✅ {filename} → {new_filename}")
# Out:
# ✅ Odata2024File.csv → 2024.csv
# ✅ Odata2019File.csv → 2019.csv
# ✅ Odata2022File.csv → 2022.csv
# ✅ Odata2023File.csv → 2023.csv
# ✅ Odata2021File.csv → 2021.csv
# ✅ Odata2020File.csv → 2020.csv
